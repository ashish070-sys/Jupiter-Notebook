# %% [markdown]
# **Ashish Singh**

# %% [markdown]
# Desktop Engineer

# %% [markdown]
# *I am interested in Data Science because i like to visualise things,i can tell a good story,i can predict what may happen if we do this and vice versa,i can do the estimation*

# %% [markdown]
# *And also because i can sense if any decisions taken will add to profit or loss to an organisation.*

# %%
2+3
# Out:
# 5

# %% [markdown]
# * Name
# * Serial Number
# * Place
# * Amount
# * Type

# %% [markdown]
# 1. One
# 2. Two
# 3. Three
# 4. Four

# %% [markdown]
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |

# %% [markdown]
# |Header|Header|Header|Header|
# |------|------|------|------|
# |Cell  |Cell  |Cell  | Cell |
# |Cell  |Cell  |Cell  | Cell |
# |Cell  |Cell  |Cell  | Cell |
# |Cell  |Cell  |Cell  | Cell |

# %% [markdown]
# ![https://www.cntraveler.com/story/why-you-should-meditate-on-a-plane-and-how-to-do-it]
